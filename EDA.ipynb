# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('Final_cleaned_dataset.csv')

# %%
data
# Out:
#                                    MOVIES  RATING  \
# 0                           Blood Red Sky     6.1
# 1     Masters of the Universe: Revelation     5.0
# 2                        The Walking Dead     8.2
# 3                          Rick and Morty     9.2
# 4                         Army of Thieves     0.0
# ...                                   ...     ...
# 6812                       The Imperfects     0.0
# 6813            AlRawabi School for Girls     0.0
# 6814                            Totenfrau     0.0
# 6815                               Arcane     0.0
# 6816                    Heart of Invictus     0.0
#
#                                                ONE-LINE   VOTES  \
# 0     A woman with a mysterious illness is forced in...   21062
# 1     The war for Eternia begins again in what may b...   17870
# 2     Sheriff Deputy Rick Grimes wakes up from a com...  885805
# 3     An animated series that follows the exploits o...  414849
# ...

# %%
plt.figure(figsize=(10,5))
plt.scatter(x=data['RATING'], y=data['VOTES'], alpha=0.7)
plt.title('Votes vs Ratings')
plt.xlabel('Ratings')
plt.ylabel('Votes')
plt.yscale('log')  # To handle large vote differences
plt.show()

# %%
data['Category 1'].replace('            ','',regex=True, inplace=True)
# Out:
# /var/folders/fw/ykslkq111b9g6j7rzr_jzkjw0000gn/T/ipykernel_37907/3524584902.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Category 1'].replace('            ','',regex=True, inplace=True)

# %%
data['Category 2'].replace('            ','',regex=True, inplace=True)
# Out:
# /var/folders/fw/ykslkq111b9g6j7rzr_jzkjw0000gn/T/ipykernel_37907/3409555783.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Category 2'].replace('            ','',regex=True, inplace=True)

# %%
data['Category 3'].replace('            ','',regex=True, inplace=True)
# Out:
# /var/folders/fw/ykslkq111b9g6j7rzr_jzkjw0000gn/T/ipykernel_37907/847038943.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Category 3'].replace('            ','',regex=True, inplace=True)

# %%
data['Category 1'].unique()
# Out:
# array(['Action', 'Animation', 'Drama', 'Crime', 'Comedy', 'Horror',
#        'Biography', 'Adventure', 'Documentary', 'Thriller', 'Game-Show',
#        'Musical', 'Mystery', 'Reality-TV', 'Family', 'Short', 'Sci-Fi',
#        'Fantasy', 'Music', 'Romance', 'History', nan, 'Film-Noir',
#        'Sport', 'Talk-Show', 'Western', 'War', 'News'], dtype=object)

# %%
data['Category 2'].unique()
# Out:
# array(['Horror', 'Action', 'Adventure', 'Crime', 'Romance', 'Drama', nan,
#        'Fantasy', 'History', 'Mystery', 'Sci-Fi', 'Thriller', 'Comedy',
#        'Family', 'Short', 'Reality-TV', 'Biography', 'Western', 'Music',
#        'Musical', 'Sport', 'War', 'Game-Show', 'Animation', 'Talk-Show',
#        'Film-Noir', 'News', 'Documentary'], dtype=object)

# %%
data['Category 3'].unique()
# Out:
# array(['Thriller', 'Adventure', 'Comedy', 'Horror', 'Drama', nan,
#        'Mystery', 'Fantasy', 'Romance', 'History', 'Crime', 'Sci-Fi',
#        'Biography', 'Music', 'Sport', 'Family', 'War', 'Musical',
#        'Western', 'Reality-TV', 'Film-Noir', 'Action', 'Game-Show',
#        'Talk-Show', 'News'], dtype=object)

# %%
new_melted=data.melt(id_vars=['MOVIES'],value_vars=['Category 1','Category 2', 'Category 3'],var_name='Category',value_name='Total Category')

# %%
new_melted['Total Category'].replace(np.nan,'Not Available',regex=True,inplace=True)

# %%
new_melted['Total Category'].unique()
# Out:
# array(['Action', 'Animation', 'Drama', 'Crime', 'Comedy', 'Horror',
#        'Biography', 'Adventure', 'Documentary', 'Thriller', 'Game-Show',
#        'Musical', 'Mystery', 'Reality-TV', 'Family', 'Short', 'Sci-Fi',
#        'Fantasy', 'Music', 'Romance', 'History', 'Not Available',
#        'Film-Noir', 'Sport', 'Talk-Show', 'Western', 'War', 'News'],
#       dtype=object)

# %%
new_melted['Total Category'].value_counts()[1:]
# Out:
# Total Category
# Drama          2742
# Comedy         2107
# Action         1210
# Documentary    1004
# Crime           938
# Animation       926
# Adventure       882
# Romance         686
# Thriller        658
# Mystery         456
# Horror          417
# Fantasy         373
# Family          347
# Biography       272
# Short           221
# Sci-Fi          218
# History         217
# Reality-TV      205
# Music           173
# Sport           140
# War              48
# Musical          47
# Game-Show        35
# Talk-Show        31
# Western          24
# News             20
# Film-Noir        11
# Name: count, dtype: int64

# %%
tracker=new_melted['Total Category'].value_counts()

# %%
plt.figure(figsize=(12,8))
tracker[1:].plot(kind='bar',color='g')
style1={'family':'serif','color':'b','size':'16'}
plt.grid()
plt.title('Catagories of movies',fontdict=style1)
plt.xlabel('Categories')
plt.ylabel('Count of movies')
plt.xticks(rotation=45)
plt.show()

# %%
new_melted
# Out:
#                                     MOVIES    Category Total Category
# 0                            Blood Red Sky  Category 1         Action
# 1      Masters of the Universe: Revelation  Category 1      Animation
# 2                         The Walking Dead  Category 1          Drama
# 3                           Rick and Morty  Category 1      Animation
# 4                          Army of Thieves  Category 1         Action
# ...                                    ...         ...            ...
# 20446                       The Imperfects  Category 3        Fantasy
# 20447            AlRawabi School for Girls  Category 3  Not Available
# 20448                            Totenfrau  Category 3  Not Available
# 20449                               Arcane  Category 3      Adventure
# 20450                    Heart of Invictus  Category 3  Not Available
#
# [20451 rows x 3 columns]

# %%
plt.figure(figsize=(8,8))
plt.pie(new_melted['Total Category'].value_counts(),autopct='%1.1f%%',pctdistance=1.2)
plt.legend(new_melted['Total Category'],title='Categories',loc="center right", bbox_to_anchor=(1.4,0.5))
plt.title('Share of every category of a movie')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.hist(temp['Release Year'], bins=30, color='g')
plt.title('Movies Released Over Time')
plt.xlabel('Release Year')
plt.ylabel('Number of Movies')
plt.show()

# %%
data['Release Year'].replace(0,2030,regex=True,inplace=True)

# %%
temp=data

# %%
temp = temp.sort_values('Release Year')

# %%
temp['Release Year'].value_counts()
# Out:
# Release Year
# 2020    886
# 2019    830
# 2018    796
# 2017    669
# 2021    584
#        ...
# 1967      1
# 1971      1
# 1972      1
# 1981      1
# 1961      1
# Name: count, Length: 79, dtype: int64

# %%
stars=data.melt(id_vars=['MOVIES'],value_vars=['Star name 1','Star name 2', 'Star name 3', 'Star name 4'],var_name='catagory',value_name='top_stars')

# %%
stars['top_stars']=stars['top_stars'].replace('Not Available',np.nan,regex=True)

# %%
stars.dropna(inplace=True)

# %%
stars = stars['top_stars'].value_counts()[:15]

# %%
plt.figure(figsize=(10,8))
stars.plot(kind='bar',color='g')
style1={'family':'serif','color':'k','size':'16'}
plt.title('Top 15 star actors',fontdict=style1)
plt.xlabel('Names of actors')
plt.ylabel('Number of movies')
plt.show()

# %%
data.columns
# Out:
# Index(['MOVIES', 'RATING', 'ONE-LINE', 'VOTES', 'RunTime', 'Category 1',
#        'Category 2', 'Category 3', 'Release Year', 'Year Till', 'Star name 1',
#        'Star name 2', 'Star name 3', 'Star name 4', 'Director Name'],
#       dtype='object')

# %%
temp_data=data

# %%
temp_data.drop(['MOVIES', 'RATING', 'ONE-LINE', 'VOTES', 'RunTime', 'Category 1',
       'Category 2', 'Category 3', 'Release Year', 'Year Till', 'Star name 1',
       'Star name 2', 'Star name 3', 'Star name 4'],axis=1,inplace=True)

temp_data['Director Name']=temp_data['Director Name'].replace('Not Available',np.nan,regex=True)

temp_data['Director Name'].dropna(inplace=True)

temp_data['Director Name'].value_counts()[:10]
# Out:
# Director Name
# Jay Karas                              16
# Directors:RaÃºl Campos, Jan Suter    15
# Marcus Raboy                           15
# Jay Chapman                            14
# Bob Bryan                              11
# Hayao Miyazaki                         10
# Lance Bangs                             9
# Ryan Polito                             9
# Kunle Afolayan                          7
# Stan Lathan                             7
# Name: count, dtype: int64

# %%
temp_data['Director Name'].value_counts()[:10].plot(kind='bar')
plt.title('Number of Movies by directors(Top 10)')
plt.xlabel('Name of Directors')
plt.ylabel('Count of Movies')
plt.show()

# %%
plt.pie(data['Year Till'].value_counts()[1:11],labels=data['Year Till'].value_counts()[1:11],autopct='%1.1f%%',pctdistance=0.8)
plt.title('Number of series released in last 10 years')
plt.legend(data['Year Till'].unique()[1:],title='Year',loc='center right',bbox_to_anchor=(1.5,0.6))
plt.show()

# %%
df=[]
i=0
while i<len(data):
    if data['RATING'][i]>9 and data['Year Till'][i]==0:
        df.append([data['MOVIES'][i],data['RATING'][i]])
        print(data['MOVIES'][i],'====>',data['RATING'][i])
    i+=1
# Out:
# Rick and Morty ====> 9.2
# The Last Dance ====> 9.1
# Cosmos: A Spacetime Odyssey ====> 9.3
# Kota Factory ====> 9.2
# Our Planet ====> 9.3
# Naui Ajusshi ====> 9.1
# Word of Honor ====> 9.1
# Kotaro Lives Alone ====> 9.2
# Yeh Meri Family ====> 9.1
# CM101MMXI Fundamentals ====> 9.2
# Stranger Things: Spotlight ====> 9.4
# Hans Zimmer: Live in Prague ====> 9.1
#  Mighty Little Bheem ====> 9.1
#  My Next Guest Needs No Introduction with David Letterman ====> 9.1
#  Middleditch & Schwartz ====> 9.1

# %%
df=pd.DataFrame(df,columns=['Movies','Rating'])

# %%
df
# Out:
#                                                Movies  Rating
# 0                                      Rick and Morty     9.2
# 1                                      The Last Dance     9.1
# 2                         Cosmos: A Spacetime Odyssey     9.3
# 3                                        Kota Factory     9.2
# 4                                          Our Planet     9.3
# 5                                        Naui Ajusshi     9.1
# 6                                       Word of Honor     9.1
# 7                                  Kotaro Lives Alone     9.2
# 8                                     Yeh Meri Family     9.1
# 9                              CM101MMXI Fundamentals     9.2
# 10                         Stranger Things: Spotlight     9.4
# 11                        Hans Zimmer: Live in Prague     9.1
# 12                                Mighty Little Bheem     9.1
# 13   My Next Guest Needs No Introduction with Davi...     9.1
# ...

# %%
plt.figure(figsize=(6,6))
plt.pie(df['Rating'],labels=df['Rating'],autopct='%1.1f%%',pctdistance=0.7)
plt.title('Movies with rating 9 and above')
plt.legend(df['Movies'],loc='center left',bbox_to_anchor=(1,0.5),title='Movie names:')
plt.show()

# %%
data.columns
# Out:
# Index(['MOVIES', 'RATING', 'ONE-LINE', 'VOTES', 'RunTime', 'Category 1',
#        'Category 2', 'Category 3', 'Release Year', 'Year Till', 'Star name 1',
#        'Star name 2', 'Star name 3', 'Star name 4', 'Director Name'],
#       dtype='object')

# %%
# Out:
# 0               Action
# 1            Animation
# 2                Drama
# 3            Animation
# 4               Action
#              ...
# 20446          Fantasy
# 20447    Not Available
# 20448    Not Available
# 20449        Adventure
# 20450    Not Available
# Name: Total Category, Length: 20451, dtype: object
